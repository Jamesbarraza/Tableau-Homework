# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('Resources/JC-201901-citibike-tripdata.csv.zip')
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
df2 = pd.read_csv('Resources/JC-201902-citibike-tripdata.csv.zip')
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
df3 = pd.read_csv('Resources/JC-201903-citibike-tripdata.csv.zip')
df3.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           306  2019-03-01 06:47:08.2110  2019-03-01 06:52:14.7150
# 1           123  2019-03-01 07:30:53.0220  2019-03-01 07:32:56.7770
# 2           328  2019-03-01 08:18:30.4030  2019-03-01 08:23:59.0590
# 3            95  2019-03-01 11:04:47.2020  2019-03-01 11:06:22.8130
# 4           169  2019-03-01 11:51:29.4170  2019-03-01 11:54:19.2120
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3267     Morris Canal
# ...

# %%
df4 = pd.read_csv('Resources/JC-201904-citibike-tripdata.csv.zip')
df4.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
df5 = pd.read_csv('Resources/JC-201905-citibike-tripdata.csv.zip')
df5.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           311  2019-05-01 00:07:36.4670  2019-05-01 00:12:47.6350
# 1           538  2019-05-01 00:08:29.2840  2019-05-01 00:17:27.9410
# 2           178  2019-05-01 00:39:36.4750  2019-05-01 00:42:34.9640
# 3           317  2019-05-01 01:24:28.0220  2019-05-01 01:29:45.5730
# 4           354  2019-05-01 01:54:39.6660  2019-05-01 02:00:34.1750
#
#    start station id start station name  start station latitude  \
# 0              3185          City Hall               40.717733
# 1              3681           Grand St               40.715178
# 2              3638      Washington St               40.724294
# 3              3206            Hilltop               40.731169
# 4              3639         Harborside               40.719252
#
#    start station longitude  end station id end station name  \
# 0               -74.043845            3279      Dixon Mills
# ...

# %%
df6 = pd.read_csv('Resources/JC-201906-citibike-tripdata.csv.zip')
df6.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1           280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2          2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3          2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4           139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
#
#    start station id start station name  start station latitude  \
# 0              3187          Warren St               40.721124
# 1              3185          City Hall               40.717733
# 2              3199       Newport Pkwy               40.728745
# 3              3199       Newport Pkwy               40.728745
# 4              3207        Oakland Ave               40.737604
#
#    start station longitude  end station id end station name  \
# 0               -74.038051            3199     Newport Pkwy
# ...

# %%
df7 = pd.read_csv('Resources/JC-201907-citibike-tripdata.csv.zip')
df7.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1           434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2           251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3           636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4           623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3206            Hilltop               40.731169
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id     end station name  \
# 0               -74.043117            3198     Heights Elevator
# ...

# %%
df8 = pd.read_csv('Resources/JC-201908-citibike-tripdata.csv.zip')
df8.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           261  2019-08-01 00:14:55.9900  2019-08-01 00:19:17.4780
# 1           172  2019-08-01 00:23:06.9910  2019-08-01 00:25:59.1480
# 2           525  2019-08-01 00:23:28.6170  2019-08-01 00:32:13.7000
# 3           219  2019-08-01 00:32:36.1410  2019-08-01 00:36:15.2730
# 4           262  2019-08-01 00:41:26.6700  2019-08-01 00:45:49.3530
#
#    start station id start station name  start station latitude  \
# 0              3205  JC Medical Center               40.716540
# 1              3279        Dixon Mills               40.721630
# 2              3199       Newport Pkwy               40.728745
# 3              3187          Warren St               40.721124
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id    end station name  \
# 0               -74.049638            3192  Liberty Light Rail
# ...

# %%
df9 = pd.read_csv('Resources/JC-201909-citibike-tripdata.csv.zip')
df9.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           145  2019-09-01 00:00:37.6920  2019-09-01 00:03:03.0100
# 1           212  2019-09-01 00:03:00.6000  2019-09-01 00:06:33.3420
# 2           569  2019-09-01 00:07:13.0020  2019-09-01 00:16:42.8610
# 3          1380  2019-09-01 00:07:25.3350  2019-09-01 00:30:26.1640
# 4          1346  2019-09-01 00:07:56.4670  2019-09-01 00:30:22.5440
#
#    start station id start station name  start station latitude  \
# 0              3640     Journal Square               40.733670
# 1              3194    McGinley Square               40.725340
# 2              3214   Essex Light Rail               40.712774
# 3              3214   Essex Light Rail               40.712774
# 4              3214   Essex Light Rail               40.712774
#
#    start station longitude  end station id            end station name  \
# 0               -74.062500            3206                     Hilltop
# ...

# %%
df10 = pd.read_csv('Resources/JC-201910-citibike-tripdata.csv.zip')
df10.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           892  2019-10-01 00:20:05.0140  2019-10-01 00:34:57.3800
# 1           374  2019-10-01 00:43:48.8790  2019-10-01 00:50:03.8190
# 2           170  2019-10-01 01:35:51.8630  2019-10-01 01:38:42.5470
# 3           946  2019-10-01 02:55:53.4000  2019-10-01 03:11:40.2710
# 4           517  2019-10-01 03:10:16.1290  2019-10-01 03:18:53.6350
#
#    start station id start station name  start station latitude  \
# 0              3275     Columbus Drive               40.718355
# 1              3211         Newark Ave               40.721525
# 2              3194    McGinley Square               40.725340
# 3              3272       Jersey & 3rd               40.723332
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id            end station name  \
# 0               -74.038914            3280                 Astor Place
# ...

# %%
df11 = pd.read_csv('Resources/JC-201911-citibike-tripdata.csv.zip')
df11.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           260  2019-11-01 00:02:53.8860  2019-11-01 00:07:14.6450
# 1           285  2019-11-01 00:05:38.6360  2019-11-01 00:10:24.1930
# 2           501  2019-11-01 00:05:43.6310  2019-11-01 00:14:05.4810
# 3           556  2019-11-01 00:07:57.0550  2019-11-01 00:17:13.9010
# 4           321  2019-11-01 00:11:44.5660  2019-11-01 00:17:05.5930
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3209       Brunswick St               40.724176
# 4              3273       Manila & 1st               40.721651
#
#    start station longitude  end station id    end station name  \
# 0               -74.043117            3203       Hamilton Park
# ...

# %%
df12 = pd.read_csv('Resources/JC-201912-citibike-tripdata.csv.zip')
df12.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1553  2019-12-01 00:07:13.9360  2019-12-01 00:33:07.6820
# 1           416  2019-12-01 00:16:40.4700  2019-12-01 00:23:36.5700
# 2           294  2019-12-01 00:20:29.7980  2019-12-01 00:25:23.9690
# 3            97  2019-12-01 00:21:13.7580  2019-12-01 00:22:51.5970
# 4           286  2019-12-01 00:29:58.0230  2019-12-01 00:34:44.2280
#
#    start station id start station name  start station latitude  \
# 0              3681           Grand St               40.715178
# 1              3195            Sip Ave               40.730897
# 2              3195            Sip Ave               40.730897
# 3              3202       Newport PATH               40.727224
# 4              3195            Sip Ave               40.730897
#
#    start station longitude  end station id  end station name  \
# 0               -74.037683            3198  Heights Elevator
# ...

# %%
citibike_2019 = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12])
citibike_2019
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...             ...                       ...                       ...
# 19723           283  2019-12-31 23:12:18.5480  2019-12-31 23:17:01.8740
# 19724           267  2019-12-31 23:19:03.5840  2019-12-31 23:23:30.6640
# 19725           379  2019-12-31 23:19:06.5830  2019-12-31 23:25:25.7970
# 19726           188  2019-12-31 23:24:00.2630  2019-12-31 23:27:09.0400
# 19727           326  2019-12-31 23:45:20.9780  2019-12-31 23:50:47.7490
#
#        start station id start station name  start station latitude  \
# ...

# %%
citibike_2019.to_csv("citibike_2019.csv", sep = ',')

# %%
member_df_jan_mar19 = pd.read_csv('Resources/data-cZMp8.csv')
member_df_jan_mar19.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/19                                              22145
# 1  1/2/19                                              38249
# 2  1/3/19                                              42181
# 3  1/4/19                                              44420
# 4  1/5/19                                              17636
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        44131
# 1                                        58975
# 2                                        62500
# 3                                        65739
# 4                                        24326
#
#    Total Annual Members (All Time)  \
# 0                           297823
# 1                           297908
# 2                           297976
# 3                           298017
# 4                           298048
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
member_df_apr_jun19 = pd.read_csv('Resources/data-MM5kM.csv')
member_df_apr_jun19.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  4/1/19                                              51399
# 1  4/2/19                                              57903
# 2  4/3/19                                              67924
# 3  4/4/19                                              66403
# 4  4/5/19                                              34470
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        75072
# 1                                        83399
# 2                                       108780
# 3                                       104268
# 4                                        46930
#
#    Total Annual Members (All Time)  \
# 0                           303223
# 1                           303386
# 2                           303552
# 3                           303699
# 4                           303766
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
member_df_apr_jun19 = member_df_apr_jun19.drop(['Column 1'], axis=1)
member_df_apr_jun19
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    4/1/19                                              51399
# 1    4/2/19                                              57903
# 2    4/3/19                                              67924
# 3    4/4/19                                              66403
# 4    4/5/19                                              34470
# ..      ...                                                ...
# 66   6/6/19                                              81323
# 67   6/7/19                                              82908
# 68   6/8/19                                              78074
# 69   6/9/19                                              73954
# 70  6/10/19                                              37019
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                         75072
# 1                                         83399
# 2                                        108780
# ...

# %%
member_df_jan_mar18 = pd.read_csv('Resources/data-7OLX8.csv')
member_df_jan_mar18.head()
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/2018                                               5499
# 1  1/2/2018                                              18818
# 2  1/3/2018                                              24299
# 3  1/4/2018                                               1922
# 4  1/5/2018                                               4972
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        11483
# 1                                        39352
# 2                                        42853
# 3                                         5328
# 4                                        14303
#
#    Total Annual Members (All Time)  \
# 0                           253490
# 1                           253558
# 2                           253591
# 3                           253604
# 4                           253614
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
member_df_apr_jun18 = pd.read_csv('Resources/data-tqNn6.csv')
member_df_apr_jun18.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  4/1/18                                              33148
# 1  4/2/18                                              22062
# 2  4/3/18                                              25883
# 3  4/4/18                                              36755
# 4  4/5/18                                              39814
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        94040
# 1                                        50418
# 2                                        59477
# 3                                        80049
# 4                                        87382
#
#    Total Annual Members (All Time)  \
# 0                           257811
# 1                           257889
# 2                           257942
# 3                           258025
# 4                           258086
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
member_df_jul_sep18 = pd.read_csv('Resources/data-FKjZg.csv')
member_df_jul_sep18.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  7/1/18                                              45265
# 1  7/2/18                                              58633
# 2  7/3/18                                              54882
# 3  7/4/18                                              48368
# 4  7/5/18                                              59471
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       120484
# 1                                       130122
# 2                                       113998
# 3                                       136287
# 4                                       133659
#
#    Total Annual Members (All Time)  \
# 0                           274813
# 1                           275016
# 2                           275157
# 3                           275304
# 4                           275487
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
member_df_oct_dec18 = pd.read_csv('Resources/data-pRAtm.csv')
member_df_oct_dec18.head()
# Out:
#       Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  10/1/18                                              71387
# 1  10/2/18                                              73113
# 2  10/3/18                                              76769
# 3  10/4/18                                              70698
# 4  10/5/18                                              74744
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       120257
# 1                                       122234
# 2                                       129720
# 3                                       116337
# 4                                       129597
#
#    Total Annual Members (All Time)  \
# 0                           290631
# 1                           290788
# 2                           290947
# 3                           291073
# 4                           291166
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
ryder_member_data_jan18_jun19 =  pd.concat([member_df_jan_mar18, member_df_apr_jun18, member_df_jul_sep18, member_df_oct_dec18, member_df_jan_mar19,member_df_apr_jun19])
ryder_member_data_jan18_jun19
# Out:
#         Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0   1/1/2018                                               5499
# 1   1/2/2018                                              18818
# 2   1/3/2018                                              24299
# 3   1/4/2018                                               1922
# 4   1/5/2018                                               4972
# ..       ...                                                ...
# 66    6/6/19                                              81323
# 67    6/7/19                                              82908
# 68    6/8/19                                              78074
# 69    6/9/19                                              73954
# 70   6/10/19                                              37019
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                         11483
# 1                                         39352
# ...

# %%
ryder_member_data_jan18_jun19.to_csv("Ryder Member Data Jan 2018 thru Jun 2019.csv", sep = ',')

# %%
member_df_jan_mar17 = pd.read_csv('Resources/data-9KAuN.csv')
member_df_jan_mar17.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/17                                              16009
# 1  1/2/17                                               8921
# 2  1/3/17                                              14198
# 3  1/4/17                                              34039
# 4  1/5/17                                              28393
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        50761
# 1                                        21545
# 2                                        25879
# 3                                        69966
# 4                                        52446
#
#    Total Annual Members (All Time)  \
# 0                           206624
# 1                           206675
# 2                           206728
# 3                           206778
# 4                           206845
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
member_df_apr_jun17 = pd.read_csv('Resources/data-Whjsi.csv')
member_df_apr_jun17.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  4/1/17                                              23849
# 1  4/2/17                                              39779
# 2  4/3/17                                              43484
# 3  4/4/17                                              29990
# 4  4/5/17                                              47635
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        67299
# 1                                       130087
# 2                                       104217
# 3                                        63091
# 4                                       108281
#
#    Total Annual Members (All Time)  \
# 0                           210739
# 1                           210915
# 2                           211075
# 3                           211171
# 4                           211310
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
member_df_jul_sep17 = pd.read_csv('Resources/data-33zqP.csv')
member_df_jul_sep17.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  7/1/17                                              36737
# 1  7/2/17                                              43035
# 2  7/3/17                                              48193
# 3  7/4/17                                              49924
# 4  7/5/17                                              60321
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       107126
# 1                                       128397
# 2                                       130240
# 3                                       146441
# 4                                       149487
#
#    Total Annual Members (All Time)  \
# 0                           228157
# 1                           228306
# 2                           228473
# 3                           228669
# 4                           228908
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
member_df_oct_dec17 = pd.read_csv('Resources/data-K8j0z.csv')
member_df_oct_dec17.head()
# Out:
#       Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  10/1/17                                              55503
# 1  10/2/17                                              65509
# 2  10/3/17                                              69105
# 3  10/4/17                                              71453
# 4  10/5/17                                              70173
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       139011
# 1                                       141748
# 2                                       135800
# 3                                       150324
# 4                                       150437
#
#    Total Annual Members (All Time)  \
# 0                           246193
# 1                           246402
# 2                           246566
# 3                           246742
# 4                           246893
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
member_df_jan_mar16 = pd.read_csv('Resources/data-rreHM.csv')
member_df_jan_mar16.head()
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/2016                                              11009
# 1  1/2/2016                                              14587
# 2  1/3/2016                                              15499
# 3  1/4/2016                                              19593
# 4  1/5/2016                                              18053
#
#    Cumulative trips (since launch):  \
# 0                          24371025
# 1                          24385612
# 2                          24401111
# 3                          24420704
# 4                          24438757
#
#    Miles traveled today (midnight to 11:59 pm)  Miles traveled to date:  \
# 0                                        24429                 44606414
# 1                                        29093                 44635507
# 2                                        29616                 44665123
# ...

# %%
member_df_jan_mar16.rename(columns = {'7-Day Passes Purchased (midnight to 11:59 pm)': '3-Day Passes Purchased (midnight to 11:59 pm)'}, inplace = True)
member_df_jan_mar16
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    1/1/2016                                              11009
# 1    1/2/2016                                              14587
# 2    1/3/2016                                              15499
# 3    1/4/2016                                              19593
# 4    1/5/2016                                              18053
# ..        ...                                                ...
# 86  3/27/2016                                              22481
# 87  3/28/2016                                              20344
# 88  3/29/2016                                              31481
# 89  3/30/2016                                              33674
# 90  3/31/2016                                              38192
#
#     Cumulative trips (since launch):  \
# 0                           24371025
# 1                           24385612
# 2                           24401111
# ...

# %%
member_df_jan_mar16 = member_df_jan_mar16.drop(['Cumulative trips (since launch):', 'Miles traveled to date:'], axis=1)
member_df_jan_mar16
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    1/1/2016                                              11009
# 1    1/2/2016                                              14587
# 2    1/3/2016                                              15499
# 3    1/4/2016                                              19593
# 4    1/5/2016                                              18053
# ..        ...                                                ...
# 86  3/27/2016                                              22481
# 87  3/28/2016                                              20344
# 88  3/29/2016                                              31481
# 89  3/30/2016                                              33674
# 90  3/31/2016                                              38192
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                         24429
# 1                                         29093
# ...

# %%
member_df_apr_jun16 = pd.read_csv('Resources/data-8eZnB.csv')
member_df_apr_jun16.head()
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  4/1/2016                                              34448
# 1  4/2/2016                                              21838
# 2  4/3/2016                                              15321
# 3  4/4/2016                                              12302
# 4  4/5/2016                                              26236
#
#    Cumulative trips (since launch):  \
# 0                          26384204
# 1                          26406042
# 2                          26421363
# 3                          26433665
# 4                          26459901
#
#    Miles traveled today (midnight to 11:59 pm)  Miles traveled to date:  \
# 0                                        67595                 48286873
# 1                                        46206                 48333079
# 2                                        28615                 48361694
# ...

# %%
member_df_apr_jun16 = member_df_apr_jun16.drop(['3-Day Passes Purchased (midnight to 11:59 pm)'], axis=1)
member_df_apr_jun16
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    4/1/2016                                              34448
# 1    4/2/2016                                              21838
# 2    4/3/2016                                              15321
# 3    4/4/2016                                              12302
# 4    4/5/2016                                              26236
# ..        ...                                                ...
# 86  6/26/2016                                              42992
# 87  6/27/2016                                              47023
# 88  6/28/2016                                              49593
# 89  6/29/2016                                              54882
# 90  6/30/2016                                              54843
#
#     Cumulative trips (since launch):  \
# 0                           26384204
# 1                           26406042
# 2                           26421363
# ...

# %%
member_df_apr_jun16.rename(columns = {'7-Day Passes Purchased (midnight to 11:59 pm)': '3-Day Passes Purchased (midnight to 11:59 pm)'}, inplace = True)
member_df_apr_jun16
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    4/1/2016                                              34448
# 1    4/2/2016                                              21838
# 2    4/3/2016                                              15321
# 3    4/4/2016                                              12302
# 4    4/5/2016                                              26236
# ..        ...                                                ...
# 86  6/26/2016                                              42992
# 87  6/27/2016                                              47023
# 88  6/28/2016                                              49593
# 89  6/29/2016                                              54882
# 90  6/30/2016                                              54843
#
#     Cumulative trips (since launch):  \
# 0                           26384204
# 1                           26406042
# 2                           26421363
# ...

# %%
member_df_apr_jun16 = member_df_apr_jun16.drop(['Cumulative trips (since launch):', 'Miles traveled to date:'], axis=1)
member_df_apr_jun16
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    4/1/2016                                              34448
# 1    4/2/2016                                              21838
# 2    4/3/2016                                              15321
# 3    4/4/2016                                              12302
# 4    4/5/2016                                              26236
# ..        ...                                                ...
# 86  6/26/2016                                              42992
# 87  6/27/2016                                              47023
# 88  6/28/2016                                              49593
# 89  6/29/2016                                              54882
# 90  6/30/2016                                              54843
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                         67595
# 1                                         46206
# ...

# %%
member_df_jul_sep16 = pd.read_csv('Resources/data-xXpEp.csv')
member_df_jul_sep16.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  7/1/16                                              39665
# 1  7/2/16                                              35835
# 2  7/3/16                                              35347
# 3  7/4/16                                              34859
# 4  7/5/16                                              43736
#
#    Cumulative trips (since launch):  \
# 0                          30074752
# 1                          30110587
# 2                          30145934
# 3                          30180793
# 4                          30224529
#
#    Miles traveled today (midnight to 11:59 pm)  Miles traveled to date:  \
# 0                                        82871                 56801553
# 1                                       111151                 56912704
# 2                                       111116                 57023820
# 3                                       109745                 57133565
# ...

# %%
member_df_jul_sep16 = member_df_jul_sep16.drop(['Cumulative trips (since launch):', 'Miles traveled to date:'], axis=1)
member_df_jul_sep16
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    7/1/16                                              39665
# 1    7/2/16                                              35835
# 2    7/3/16                                              35347
# 3    7/4/16                                              34859
# 4    7/5/16                                              43736
# ..      ...                                                ...
# 87  9/26/16                                              61120
# 88  9/27/16                                              61334
# 89  9/28/16                                              59456
# 90  9/29/16                                              55550
# 91  9/30/16                                              21368
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                         82871
# 1                                        111151
# 2                                        111116
# ...

# %%
member_df_oct_dec16 = pd.read_csv('Resources/data-gRmSF.csv')
member_df_oct_dec16.head()
# Out:
#         Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  10/1/2016                                              39809
# 1  10/2/2016                                              41018
# 2  10/3/2016                                              56369
# 3  10/4/2016                                              60196
# 4  10/5/2016                                              65031
#
#   Cumulative trips (since launch):  \
# 0                       34,659,659
# 1                       34,700,677
# 2                       34,757,046
# 3                       34,817,242
# 4                       34,882,273
#
#    Miles traveled today (midnight to 11:59 pm) Miles traveled to date:  \
# 0                                        91771              67,278,343
# 1                                       100425              67,378,768
# 2                                       116682              67,495,450
# 3                                       123551              67,619,001
# ...

# %%
member_df_oct_dec16 = member_df_oct_dec16.drop(['Cumulative trips (since launch):', 'Miles traveled to date:'], axis=1)
member_df_oct_dec16
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0   10/1/2016                                              39809
# 1   10/2/2016                                              41018
# 2   10/3/2016                                              56369
# 3   10/4/2016                                              60196
# 4   10/5/2016                                              65031
# ..        ...                                                ...
# 87   12/27/16                                              25946
# 88   12/28/16                                              23596
# 89   12/29/16                                              13202
# 90   12/30/16                                              21366
# 91   12/31/16                                              15925
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                         91771
# 1                                        100425
# ...

# %%
ryder_member_data_jan16_dec17 =  pd.concat([member_df_jan_mar16, member_df_apr_jun16, member_df_jul_sep16, member_df_oct_dec16, member_df_jan_mar17, member_df_apr_jun17, member_df_jul_sep17, member_df_oct_dec17])
ryder_member_data_jan16_dec17
# Out:
#         Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0   1/1/2016                                              11009
# 1   1/2/2016                                              14587
# 2   1/3/2016                                              15499
# 3   1/4/2016                                              19593
# 4   1/5/2016                                              18053
# ..       ...                                                ...
# 87  12/27/17                                              16365
# 88  12/28/17                                              13419
# 89  12/29/17                                              13759
# 90  12/30/17                                               5956
# 91  12/31/17                                               6569
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                         24429
# 1                                         29093
# ...

# %%
ryder_member_data_jan16_dec17.to_csv("Ryder Member Data Jan 2016 thru Dec 2017.csv")
